# %%
import glob
import os
import re
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
from collections import OrderedDict, Callable

class DefaultOrderedDict(OrderedDict):
    # Source: http://stackoverflow.com/a/6190500/562769
    def __init__(self, default_factory=None, *a, **kw):
        if (default_factory is not None and
           not isinstance(default_factory, Callable)):
            raise TypeError('first argument must be callable')
        OrderedDict.__init__(self, *a, **kw)
        self.default_factory = default_factory

    def __getitem__(self, key):
        try:
            return OrderedDict.__getitem__(self, key)
        except KeyError:
            return self.__missing__(key)

    def __missing__(self, key):
        if self.default_factory is None:
            raise KeyError(key)
        self[key] = value = self.default_factory()
        return value

    def __reduce__(self):
        if self.default_factory is None:
            args = tuple()
        else:
            args = self.default_factory,
        return type(self), args, None, None, self.items()

    def copy(self):
        return self.__copy__()

    def __copy__(self):
        return type(self)(self.default_factory, self)

    def __deepcopy__(self, memo):
        import copy
        return type(self)(self.default_factory,
                          copy.deepcopy(self.items()))

    def __repr__(self):
        return 'OrderedDefaultDict(%s, %s)' % (self.default_factory,
                                               OrderedDict.__repr__(self))
# Out:
# /home/wooks/anaconda3/envs/avidnet/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Extract mean score

# %%
# if not os.path.isdir('./results/extracted'):
#     os.mkdir('./results/extracted')

# %%
# p = re.compile('0[.]\d{4}\s\D{2}0[.]\d{2}\D') #[0.숫자4개 +띄어쓰기 + 문자 2개 0.숫자 2개 + 문자 1개
# data_paths = glob.glob('/home/aiffel0042/github_project/AVIDNet/results/*.txt')
# data_paths
# Out:
# []

# %%
# for ori_data_path, data_path in zip(ori_data_paths, data_paths): # 데이터 경로에서 txt파일을 하나씩 불러온다.
#     with open(ori_data_path,'r') as f: 
#         all_data = f.read() # 전체 txt line을 읽어온다.
#         all_data = all_data.split('\n') # 띄어쓰기 기준으로 나눔
#         metric_line = all_data[-6:-2] # hard coding.. 맨 뒤 mean result 부분
#         extract = p.findall(str(metric_line))# 정규표현식에 맞는것만 뽑아내서 extract에 저장
#     with open(data_path,'a') as f:
#         for extract_line in extract:
#             f.write(str(extract_line)+'\n')

# %% [markdown]
# ## Extract mean best scores among all random seeds

# %%
# input_dir = './results/lb25_mu1'
# input_dir = './results/lb50_mu1
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.01'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.005'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.004'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.003'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.002'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.001'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0009'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0008'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0007'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0006'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0005'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0001'
out_dir = './results/extracted_for_best'
# out_fname = 'lb25-mu1-b8,r0,1,2,3.csv'
# out_fname = 'lb50-mu1-b8,r0,1,2,3.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.01.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.005.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.004.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.003.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.002.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.001.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0009.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0008.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0007.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0006.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0005.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0001.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
input_dir = './results/lr_with_warmup/lr0.01'
# input_dir = './results/lr_with_warmup/lr0.009'
# input_dir = './results/lr_with_warmup/lr0.008'
# input_dir = './results/lr_with_warmup/lr0.007'
# input_dir = './results/lr_with_warmup/lr0.006'
# input_dir = './results/lr_with_warmup/lr0.005'
# input_dir = './results/lr_with_warmup/lr0.004'
# input_dir = './results/lr_with_warmup/lr0.003'
# input_dir = './results/lr_with_warmup/lr0.002'
# input_dir = './results/lr_with_warmup/lr0.001'
out_dir = './results/extracted_for_best'
out_fname = 'lr_with_warmup-lr0.01.csv'
# out_fname = 'lr_with_warmup-lr0.009.csv'
# out_fname = 'lr_with_warmup-lr0.008.csv'
# out_fname = 'lr_with_warmup-lr0.007.csv'
# out_fname = 'lr_with_warmup-lr0.006.csv'
# out_fname = 'lr_with_warmup-lr0.005.csv'
# out_fname = 'lr_with_warmup-lr0.004.csv'
# out_fname = 'lr_with_warmup-lr0.003.csv'
# out_fname = 'lr_with_warmup-lr0.002.csv'
# out_fname = 'lr_with_warmup-lr0.001.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# input_dir = './results/fixaugs'
# out_dir = './results/extracted_for_best'
# out_fname = 'fixaugs.csv'
# if not os.path.isdir(out_dir):
#     os.makedirs(out_dir)

# %%
# input_dir = './results/aug_test_for_nl25'
# input_dir = './results/aug_test_for_nl50'
# input_dir = './results/aug_test_for_nl100'
# input_dir = './results/aug_test_for_nl150'
# input_dir = './results/aug_test_for_nl200'
# input_dir = './results/aug_test_for_nl300'
# input_dir = './results/aug_test_for_nl25_accumulated'
# input_dir = './results/aug_test_for_nl50_accumulated'
# input_dir = './results/aug_test_for_nl100_accumulated'
# input_dir = './results/aug_test_for_nl100_accumulated_e40'
input_dir = './results/nl50_aug_result'
out_dir = './results/extracted_for_best'
# out_fname = 'aug_test_for_nl25.csv'
# out_fname = 'aug_test_for_nl50.csv'
# out_fname = 'aug_test_for_nl100.csv'
# out_fname = 'aug_test_for_nl150.csv'
# out_fname = 'aug_test_for_nl200.csv'
# out_fname = 'aug_test_for_nl300.csv'
# out_fname = 'aug_test_for_nl25_accumulated.csv'
# out_fname = 'aug_test_for_nl50_accumulated.csv'
# out_fname = 'aug_test_for_nl100_accumulated.csv'
# out_fname = 'aug_test_for_nl100_accumulated_e40.csv'
out_fname = 'nl50_aug_result.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# input_dir = './results/aug_test_for_fixmatch_nl50'
# input_dir = './results/aug_test_for_fixmatch_nl100'
# input_dir = './results/aug_test_for_fixmatch_nl150'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_0.5'
input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_0.8'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_1.0'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_1.2'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_1.5'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_2.0'
out_dir = './results/extracted_for_best'
# out_fname = 'aug_test_for_fixmatch_nl50.csv'
# out_fname = 'aug_test_for_fixmatch_nl100.csv'
# out_fname = 'aug_test_for_fixmatch_nl150.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma0.5.csv'
out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma0.8.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma1.0.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma1.2.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma1.5.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma2.0.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# input_dir = './results/randaug_tests/k3'
input_dir = './results/randaug_tests/k5'
# input_dir = './results/randaug_tests/k7'
# input_dir = './results/randaug_tests/k5-fg2'
# input_dir = './results/randaug_tests/fixmatch'
out_dir = './results/extracted_for_best'
out_fname = 'randaug_tests_for_k5.csv'
# out_fname = 'randaug_tests_for_k7.csv'
add_dir = False
# add_dir = True
# add_input_dirs = ['./results/randaug_tests/k5_f4']
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# ori_data_paths = glob.glob(f'{input_dir}/*.txt')
# # fix_cols = ['th0.95-lb1.0', 'th0.95-lb0.75', 'th0.95-lb0.5',
# #             'th0.98-lb1.0', 'th0.98-lb0.75', 'th0.98-lb0.5']
# # fix_cols = ['aug1-th0.95-lb1.0', 'aug2-th0.95-lb1.0', 'aug3-th0.95-lb1.0']
# # fix_cols = ['aug1-th0.95-lb1.0', 'aug2-th0.95-lb1.0', 'aug3-th0.95-lb1.0']
# # base_cols = [f'bf{i}' for i in range(21)]
# # base_cols = ['bf0', 'bf9', 'bf9,16', 'bf16,9', 'bf16,9,3'] # nl25
# # base_cols = ['bf0', 'bf50:13', 'bf50:13,9', 'bf50:9,13', 'bf50:13,9,7'] # nl50
# # base_cols = ['bf0', 'bf100:9', 'bf14', 'bf100:9,14', 'bf100:14,9', 'bf3', 'bf100:9,14,3'] # nl100
# # base_cols = ['bf9,14', 'bf14,9', 'bf9,14,3', "bf9,3,14", "bf14,9,3", "bf14,3,9", "bf3,9,14", "bf3,14,9"] # nl100_e40
# # base_cols = ["bf13,9", "bf9,13", "bf13,9,8", "bf13,8,9", "bf9,13,8", "bf9,8,13", "bf8,13,9", "bf8,9,13"] # nl100_e40

# # Extract paths for each colums such as baseline, fix-th0.95-lb1.0 and so on
# data_paths_dict = DefaultOrderedDict(list)
# for ori_data_path in ori_data_paths:
#     # Exclude the case of the random seed 4 because of performance
#     if '-r4-' not in ori_data_path:
#         # Baseline
#         if 'baseline' in ori_data_path:
# #             data_paths_dict['baseline'].append(ori_data_path)
#             for base_col in base_cols:
#                 if base_col + '.' in ori_data_path:
#                     data_paths_dict[f'base-{base_col}'].append(ori_data_path)
#                     break
                    
#         # FixMatch
#         else:
#             for fix_col in fix_cols:
#                 if fix_col in ori_data_path:
# #                 if fix_col[:5] in ori_data_path and fix_col[5:] in ori_data_path:
#                     data_paths_dict[f'fix-{fix_col}'].append(ori_data_path)
# #                     data_paths_dict[f'fix{fix_col}'].append(ori_data_path)
#                     break

# data_paths_dict['baseline'][:3]

# %%
ori_data_paths = glob.glob(f'{input_dir}/**/*.txt', recursive=True)
if add_dir:
    for add_input_dir in add_input_dirs:
        ori_data_paths.extend(glob.glob(f'{add_input_dir}/*.txt'))

# Extract paths for each colums such as baseline, fix-th0.95-lb1.0 and so on
fm_cols = []
data_paths_dict = DefaultOrderedDict(list)
for ori_data_path in ori_data_paths:
    cond = '-'.join(ori_data_path.split('-')[:5])
    cond = cond.split('/')[-1].replace('nl25', 'nl025')
    cond = cond.split('/')[-1].replace('nl50', 'nl050')
    if cond not in fm_cols:
        fm_cols.append(cond)
    data_paths_dict[cond].append(ori_data_path)
    # Baseline
#     if 'baseline' in ori_data_path:
# #             data_paths_dict['baseline'].append(ori_data_path)
#         for base_col in base_cols:
#             if base_col + '.' in ori_data_path:
#                 data_paths_dict[f'base-{base_col}'].append(ori_data_path)
#                 break

#     # FixMatch
#     else:
#         for fix_col in fix_cols:
#             if fix_col in ori_data_path:
# #                 if fix_col[:5] in ori_data_path and fix_col[5:] in ori_data_path:
#                 data_paths_dict[f'fix-{fix_col}'].append(ori_data_path)
# #                     data_paths_dict[f'fix{fix_col}'].append(ori_data_path)
#                 break

fm_cols.sort()
len(data_paths_dict)
# Out:
# 38

# %%
p = re.compile('1[.]\d{4}|0[.]\d{4}') #[0.숫자4개]

cols = ('acc-all', 'ppv-all', 'ppv-covid', 'ppv-pneumonia', 'ppv-normal',
        'recall-all', 'recall-covid', 'recall-pneumonia', 'recall-normal',
        'f1-all', 'f1-covid', 'f1-pneumonia', 'f1-normal')
metrics_dfs = {}
for col, data_paths in data_paths_dict.items(): # 데이터 경로에서 txt파일을 하나씩 불러온다.
    metrics_dfs[col] = pd.DataFrame([], columns=cols)
    for ori_data_path in data_paths:
        with open(ori_data_path, 'r') as f: 
            all_data = f.read() # 전체 txt line을 읽어온다.
            all_data = all_data.split('\n') # 띄어쓰기 기준으로 나눔
            if 'baseline' in ori_data_path:
#                 candidates = ((327, 332), (662, 667), (997, 1002),
#                               (1332, 1337), (1667, 1672))
                candidates = ((327, 332), (662, 667), (997, 1002))
#                 candidates = ((647, 652), (1302, 1307), (1957, 1962))
                if add_dir and 'k5_f4' in ori_data_path: # 새로 추가된 Fold 4,5 결과
                    candidates = ((327, 332),)
            else:
#                 candidates = ((347, 352), (702, 707), (1057, 1062),
#                               (1412, 1417), (1767, 1772))
                candidates = ((347, 352), (702, 707), (1057, 1062))
                if add_dir and 'k5_f4' in ori_data_path: # 새로 추가된 Fold 4,5 결과
                    candidates = ((347, 352),)
            metrics = []
            for s_idx, e_idx in candidates:
                metric_line = all_data[s_idx:e_idx] # hard coding.. best result 부분
                metrics.append(list(map(float, p.findall(str(metric_line)))))# 정규표현식에 맞는것만 뽑기

            metrics_dfs[col] = pd.concat((metrics_dfs[col],
                                         pd.DataFrame(metrics, columns=cols))).reset_index(drop=True)

# fm_cols = ['baseline'] + [f'fix-{c}' for c in fix_cols]
# fm_cols = ['baseline'] + [f'fix{c}' for c in fix_cols]
# fm_cols = [f'base-{c}' for c in base_cols]
final_metrics_df = pd.DataFrame([], columns=cols)
for fm_col in fm_cols:
    final_metrics = []
    for col in cols:
        best_metrics = metrics_dfs[fm_col][col].to_numpy()
        mean, std = best_metrics.mean(), best_metrics.std()
        final_metrics.append(f'{mean:.4f} (±{std:.2f})')
        
    final_metrics_df = final_metrics_df.append(pd.DataFrame([final_metrics], columns=cols, index=(fm_col,)))

final_metrics_df
# Out:
#                                     acc-all         ppv-all       ppv-covid  \
# baseline-nl025-m1-fg1.0-b16  0.8044 (±0.02)  0.8125 (±0.02)  0.8928 (±0.03)
# baseline-nl050-m1-fg1.0-b16  0.8525 (±0.02)  0.8590 (±0.01)  0.9138 (±0.02)
# baseline-nl100-m1-fg1.0-b16  0.8706 (±0.01)  0.8728 (±0.01)  0.9043 (±0.02)
# baseline-nl150-m1-fg1.0-b16  0.8878 (±0.01)  0.8890 (±0.01)  0.9102 (±0.03)
# fixmatch-nl025-m1-fg0.5-b16  0.8081 (±0.02)  0.8168 (±0.02)  0.9004 (±0.02)
# fixmatch-nl025-m1-fg1.0-b16  0.8075 (±0.02)  0.8161 (±0.02)  0.8978 (±0.02)
# fixmatch-nl025-m1-fg1.5-b16  0.8081 (±0.02)  0.8168 (±0.02)  0.8989 (±0.02)
# fixmatch-nl025-m2-fg0.5-b16  0.8058 (±0.03)  0.8167 (±0.02)  0.9067 (±0.02)
# fixmatch-nl025-m2-fg1.0-b16  0.8067 (±0.03)  0.8166 (±0.03)  0.9015 (±0.03)
# fixmatch-nl025-m2-fg1.5-b16  0.8058 (±0.03)  0.8161 (±0.02)  0.9034 (±0.03)
# fixmatch-nl025-m3-fg0.5-b16  0.8058 (±0.03)  0.8137 (±0.02)  0.8905 (±0.03)
# fixmatch-nl025-m3-fg1.0-b16  0.8064 (±0.03)  0.8138 (±0.02)  0.8863 (±0.03)
# fixmatch-nl025-m3-fg1.5-b16  0.8067 (±0.03)  0.8142 (±0.02)  0.8877 (±0.03)
# fixmatch-nl050-m1-fg0.5-b16  0.8494 (±0.01)  0.8534 (±0.01)  0.8998 (±0.03)
# fixmatch-nl050-m1-fg1.0-b16  0.8464 (±0.01)  0.8499 (±0.01)  0.8936 (±0.04)
# fixmatch-nl050-m1-fg1.5-b16  0.8506 (±0.02)  0.8545 (±0.02)  0.9062 (±0.03)
# fixmatch-nl050-m2-fg0.5-b16  0.8600 (±0.01)  0.8638 (±0.02)  0.9244 (±0.04)
# fixmatch-nl050-m2-fg1.0-b16  0.8589 (±0.02)  0.8628 (±0.02)  0.9209 (±0.04)
# fixmatch-nl050-m2-fg1.5-b16  0.8569 (±0.02)  0.8595 (±0.02)  0.9068 (±0.03)
# fixmatch-nl050-m3-fg0.5-b16  0.8625 (±0.02)  0.8652 (±0.02)  0.9095 (±0.03)
# fixmatch-nl050-m3-fg1.0-b16  0.8628 (±0.02)  0.8660 (±0.02)  0.9211 (±0.02)
# fixmatch-nl050-m3-fg1.5-b16  0.8639 (±0.01)  0.8663 (±0.01)  0.9119 (±0.03)
# fixmatch-nl100-m1-fg0.5-b16  0.8686 (±0.01)  0.8740 (±0.01)  0.9335 (±0.03)
# fixmatch-nl100-m1-fg1.0-b16  0.8775 (±0.01)  0.8803 (±0.01)  0.9257 (±0.03)
# fixmatch-nl100-m1-fg1.5-b16  0.8711 (±0.02)  0.8744 (±0.01)  0.9262 (±0.02)
# fixmatch-nl100-m1-fg2.0-b16  0.8704 (±0.01)  0.8734 (±0.01)  0.9191 (±0.03)
# fixmatch-nl100-m2-fg0.5-b16  0.8767 (±0.01)  0.8806 (±0.01)  0.9320 (±0.03)
# fixmatch-nl100-m2-fg1.0-b16  0.8761 (±0.01)  0.8798 (±0.01)  0.9282 (±0.02)
# fixmatch-nl100-m2-fg1.5-b16  0.8739 (±0.02)  0.8771 (±0.01)  0.9165 (±0.03)
# fixmatch-nl100-m3-fg0.5-b16  0.8778 (±0.01)  0.8802 (±0.01)  0.9229 (±0.03)
# fixmatch-nl100-m3-fg1.0-b16  0.8750 (±0.01)  0.8769 (±0.01)  0.9131 (±0.02)
# fixmatch-nl100-m3-fg1.5-b16  0.8719 (±0.01)  0.8741 (±0.01)  0.9167 (±0.02)
# fixmatch-nl150-m1-fg0.5-b16  0.8944 (±0.01)  0.8979 (±0.01)  0.9505 (±0.02)
# fixmatch-nl150-m1-fg1.0-b16  0.8906 (±0.01)  0.8941 (±0.01)  0.9437 (±0.03)
# fixmatch-nl150-m1-fg1.5-b16  0.8964 (±0.01)  0.8988 (±0.01)  0.9205 (±0.03)
# fixmatch-nl150-m2-fg0.5-b16  0.8933 (±0.01)  0.8957 (±0.01)  0.9304 (±0.02)
# fixmatch-nl150-m2-fg1.0-b16  0.8889 (±0.01)  0.8911 (±0.01)  0.9334 (±0.02)
# fixmatch-nl150-m2-fg1.5-b16  0.8919 (±0.01)  0.8940 (±0.01)  0.9305 (±0.03)
#
#                               ppv-pneumonia      ppv-normal      recall-all  \
# baseline-nl025-m1-fg1.0-b16  0.7456 (±0.04)  0.7990 (±0.02)  0.8044 (±0.02)
# baseline-nl050-m1-fg1.0-b16  0.8274 (±0.06)  0.8357 (±0.03)  0.8525 (±0.02)
# baseline-nl100-m1-fg1.0-b16  0.8438 (±0.04)  0.8701 (±0.02)  0.8706 (±0.01)
# baseline-nl150-m1-fg1.0-b16  0.8777 (±0.02)  0.8792 (±0.03)  0.8878 (±0.01)
# fixmatch-nl025-m1-fg0.5-b16  0.7500 (±0.04)  0.8001 (±0.03)  0.8081 (±0.02)
# fixmatch-nl025-m1-fg1.0-b16  0.7523 (±0.03)  0.7982 (±0.04)  0.8075 (±0.02)
# fixmatch-nl025-m1-fg1.5-b16  0.7510 (±0.03)  0.8004 (±0.04)  0.8081 (±0.02)
# fixmatch-nl025-m2-fg0.5-b16  0.7467 (±0.06)  0.7965 (±0.04)  0.8058 (±0.03)
# fixmatch-nl025-m2-fg1.0-b16  0.7481 (±0.05)  0.8001 (±0.03)  0.8067 (±0.03)
# fixmatch-nl025-m2-fg1.5-b16  0.7481 (±0.05)  0.7969 (±0.04)  0.8058 (±0.03)
# fixmatch-nl025-m3-fg0.5-b16  0.7490 (±0.05)  0.8017 (±0.02)  0.8058 (±0.03)
# fixmatch-nl025-m3-fg1.0-b16  0.7481 (±0.05)  0.8070 (±0.02)  0.8064 (±0.03)
# fixmatch-nl025-m3-fg1.5-b16  0.7486 (±0.05)  0.8062 (±0.02)  0.8067 (±0.03)
# fixmatch-nl050-m1-fg0.5-b16  0.8254 (±0.04)  0.8348 (±0.03)  0.8494 (±0.01)
# fixmatch-nl050-m1-fg1.0-b16  0.8215 (±0.03)  0.8346 (±0.03)  0.8464 (±0.01)
# fixmatch-nl050-m1-fg1.5-b16  0.8175 (±0.04)  0.8397 (±0.03)  0.8506 (±0.02)
# fixmatch-nl050-m2-fg0.5-b16  0.8334 (±0.02)  0.8335 (±0.02)  0.8600 (±0.01)
# fixmatch-nl050-m2-fg1.0-b16  0.8257 (±0.03)  0.8416 (±0.02)  0.8589 (±0.02)
# fixmatch-nl050-m2-fg1.5-b16  0.8368 (±0.03)  0.8347 (±0.02)  0.8569 (±0.02)
# fixmatch-nl050-m3-fg0.5-b16  0.8470 (±0.04)  0.8390 (±0.02)  0.8625 (±0.02)
# fixmatch-nl050-m3-fg1.0-b16  0.8475 (±0.03)  0.8295 (±0.02)  0.8628 (±0.02)
# fixmatch-nl050-m3-fg1.5-b16  0.8447 (±0.03)  0.8423 (±0.02)  0.8639 (±0.01)
# fixmatch-nl100-m1-fg0.5-b16  0.8545 (±0.05)  0.8339 (±0.03)  0.8686 (±0.01)
# fixmatch-nl100-m1-fg1.0-b16  0.8545 (±0.04)  0.8606 (±0.02)  0.8775 (±0.01)
# fixmatch-nl100-m1-fg1.5-b16  0.8448 (±0.05)  0.8521 (±0.02)  0.8711 (±0.02)
# fixmatch-nl100-m1-fg2.0-b16  0.8557 (±0.05)  0.8455 (±0.02)  0.8704 (±0.01)
# fixmatch-nl100-m2-fg0.5-b16  0.8505 (±0.04)  0.8591 (±0.03)  0.8767 (±0.01)
# fixmatch-nl100-m2-fg1.0-b16  0.8568 (±0.05)  0.8542 (±0.02)  0.8761 (±0.01)
# fixmatch-nl100-m2-fg1.5-b16  0.8457 (±0.05)  0.8690 (±0.02)  0.8739 (±0.02)
# fixmatch-nl100-m3-fg0.5-b16  0.8526 (±0.03)  0.8652 (±0.02)  0.8778 (±0.01)
# fixmatch-nl100-m3-fg1.0-b16  0.8562 (±0.04)  0.8613 (±0.03)  0.8750 (±0.01)
# fixmatch-nl100-m3-fg1.5-b16  0.8527 (±0.03)  0.8531 (±0.02)  0.8719 (±0.01)
# fixmatch-nl150-m1-fg0.5-b16  0.8922 (±0.04)  0.8509 (±0.02)  0.8944 (±0.01)
# fixmatch-nl150-m1-fg1.0-b16  0.8876 (±0.03)  0.8509 (±0.02)  0.8906 (±0.01)
# fixmatch-nl150-m1-fg1.5-b16  0.9139 (±0.03)  0.8621 (±0.02)  0.8964 (±0.01)
# fixmatch-nl150-m2-fg0.5-b16  0.9003 (±0.03)  0.8563 (±0.02)  0.8933 (±0.01)
# fixmatch-nl150-m2-fg1.0-b16  0.8895 (±0.02)  0.8505 (±0.02)  0.8889 (±0.01)
# fixmatch-nl150-m2-fg1.5-b16  0.8942 (±0.03)  0.8573 (±0.01)  0.8919 (±0.01)
#
#                                recall-covid recall-pneumonia   recall-normal  \
# baseline-nl025-m1-fg1.0-b16  0.7542 (±0.03)   0.8425 (±0.02)  0.8167 (±0.07)
# baseline-nl050-m1-fg1.0-b16  0.8367 (±0.06)   0.8750 (±0.03)  0.8458 (±0.05)
# baseline-nl100-m1-fg1.0-b16  0.8792 (±0.03)   0.8850 (±0.02)  0.8475 (±0.04)
# baseline-nl150-m1-fg1.0-b16  0.9125 (±0.03)   0.8842 (±0.02)  0.8667 (±0.04)
# fixmatch-nl025-m1-fg0.5-b16  0.7575 (±0.04)   0.8542 (±0.03)  0.8125 (±0.07)
# fixmatch-nl025-m1-fg1.0-b16  0.7525 (±0.05)   0.8533 (±0.03)  0.8167 (±0.06)
# fixmatch-nl025-m1-fg1.5-b16  0.7525 (±0.05)   0.8583 (±0.03)  0.8133 (±0.05)
# fixmatch-nl025-m2-fg0.5-b16  0.7525 (±0.04)   0.8625 (±0.02)  0.8025 (±0.07)
# fixmatch-nl025-m2-fg1.0-b16  0.7542 (±0.04)   0.8608 (±0.02)  0.8050 (±0.07)
# fixmatch-nl025-m2-fg1.5-b16  0.7525 (±0.04)   0.8633 (±0.02)  0.8017 (±0.07)
# fixmatch-nl025-m3-fg0.5-b16  0.7708 (±0.02)   0.8542 (±0.02)  0.7925 (±0.07)
# fixmatch-nl025-m3-fg1.0-b16  0.7767 (±0.02)   0.8533 (±0.02)  0.7892 (±0.06)
# fixmatch-nl025-m3-fg1.5-b16  0.7750 (±0.02)   0.8525 (±0.02)  0.7925 (±0.07)
# fixmatch-nl050-m1-fg0.5-b16  0.8333 (±0.03)   0.8675 (±0.02)  0.8475 (±0.05)
# fixmatch-nl050-m1-fg1.0-b16  0.8367 (±0.04)   0.8575 (±0.02)  0.8450 (±0.05)
# fixmatch-nl050-m1-fg1.5-b16  0.8317 (±0.05)   0.8658 (±0.02)  0.8542 (±0.04)
# fixmatch-nl050-m2-fg0.5-b16  0.8375 (±0.03)   0.8792 (±0.01)  0.8633 (±0.03)
# fixmatch-nl050-m2-fg1.0-b16  0.8450 (±0.04)   0.8767 (±0.03)  0.8550 (±0.03)
# fixmatch-nl050-m2-fg1.5-b16  0.8467 (±0.04)   0.8692 (±0.02)  0.8550 (±0.03)
# fixmatch-nl050-m3-fg0.5-b16  0.8583 (±0.05)   0.8667 (±0.02)  0.8625 (±0.03)
# fixmatch-nl050-m3-fg1.0-b16  0.8458 (±0.03)   0.8700 (±0.03)  0.8725 (±0.03)
# fixmatch-nl050-m3-fg1.5-b16  0.8608 (±0.04)   0.8725 (±0.02)  0.8583 (±0.02)
# fixmatch-nl100-m1-fg0.5-b16  0.8450 (±0.02)   0.8717 (±0.02)  0.8892 (±0.04)
# fixmatch-nl100-m1-fg1.0-b16  0.8833 (±0.04)   0.8842 (±0.02)  0.8650 (±0.03)
# fixmatch-nl100-m1-fg1.5-b16  0.8625 (±0.03)   0.8867 (±0.02)  0.8642 (±0.03)
# fixmatch-nl100-m1-fg2.0-b16  0.8711 (±0.04)   0.8778 (±0.02)  0.8622 (±0.04)
# fixmatch-nl100-m2-fg0.5-b16  0.8667 (±0.03)   0.8908 (±0.02)  0.8725 (±0.04)
# fixmatch-nl100-m2-fg1.0-b16  0.8767 (±0.04)   0.8775 (±0.03)  0.8742 (±0.04)
# fixmatch-nl100-m2-fg1.5-b16  0.8833 (±0.05)   0.8858 (±0.03)  0.8525 (±0.04)
# fixmatch-nl100-m3-fg0.5-b16  0.8875 (±0.04)   0.8800 (±0.02)  0.8658 (±0.03)
# fixmatch-nl100-m3-fg1.0-b16  0.8908 (±0.03)   0.8758 (±0.02)  0.8583 (±0.04)
# fixmatch-nl100-m3-fg1.5-b16  0.8758 (±0.03)   0.8758 (±0.02)  0.8642 (±0.04)
# fixmatch-nl150-m1-fg0.5-b16  0.8875 (±0.02)   0.8742 (±0.01)  0.9217 (±0.03)
# fixmatch-nl150-m1-fg1.0-b16  0.8783 (±0.03)   0.8750 (±0.02)  0.9183 (±0.03)
# fixmatch-nl150-m1-fg1.5-b16  0.9158 (±0.04)   0.8650 (±0.03)  0.9083 (±0.03)
# fixmatch-nl150-m2-fg0.5-b16  0.8922 (±0.04)   0.8711 (±0.02)  0.9167 (±0.02)
# fixmatch-nl150-m2-fg1.0-b16  0.8956 (±0.02)   0.8589 (±0.03)  0.9122 (±0.02)
# fixmatch-nl150-m2-fg1.5-b16  0.9044 (±0.03)   0.8644 (±0.04)  0.9067 (±0.02)
#
#                                      f1-all        f1-covid    f1-pneumonia  \
# baseline-nl025-m1-fg1.0-b16  0.8046 (±0.02)  0.8170 (±0.02)  0.7906 (±0.03)
# baseline-nl050-m1-fg1.0-b16  0.8528 (±0.02)  0.8718 (±0.03)  0.8479 (±0.02)
# baseline-nl100-m1-fg1.0-b16  0.8706 (±0.01)  0.8910 (±0.01)  0.8631 (±0.02)
# baseline-nl150-m1-fg1.0-b16  0.8877 (±0.01)  0.9106 (±0.01)  0.8806 (±0.01)
# fixmatch-nl025-m1-fg0.5-b16  0.8083 (±0.02)  0.8221 (±0.03)  0.7977 (±0.02)
# fixmatch-nl025-m1-fg1.0-b16  0.8076 (±0.02)  0.8179 (±0.03)  0.7987 (±0.02)
# fixmatch-nl025-m1-fg1.5-b16  0.8082 (±0.02)  0.8183 (±0.03)  0.8003 (±0.02)
# fixmatch-nl025-m2-fg0.5-b16  0.8064 (±0.03)  0.8215 (±0.02)  0.7992 (±0.03)
# fixmatch-nl025-m2-fg1.0-b16  0.8071 (±0.03)  0.8205 (±0.02)  0.7994 (±0.03)
# fixmatch-nl025-m2-fg1.5-b16  0.8063 (±0.03)  0.8201 (±0.02)  0.8005 (±0.03)
# fixmatch-nl025-m3-fg0.5-b16  0.8064 (±0.03)  0.8260 (±0.02)  0.7973 (±0.03)
# fixmatch-nl025-m3-fg1.0-b16  0.8070 (±0.03)  0.8274 (±0.02)  0.7965 (±0.03)
# fixmatch-nl025-m3-fg1.5-b16  0.8072 (±0.03)  0.8271 (±0.02)  0.7964 (±0.03)
# fixmatch-nl050-m1-fg0.5-b16  0.8496 (±0.01)  0.8646 (±0.02)  0.8450 (±0.02)
# fixmatch-nl050-m1-fg1.0-b16  0.8465 (±0.01)  0.8629 (±0.02)  0.8385 (±0.01)
# fixmatch-nl050-m1-fg1.5-b16  0.8508 (±0.02)  0.8662 (±0.02)  0.8403 (±0.02)
# fixmatch-nl050-m2-fg0.5-b16  0.8604 (±0.01)  0.8782 (±0.02)  0.8554 (±0.02)
# fixmatch-nl050-m2-fg1.0-b16  0.8593 (±0.02)  0.8802 (±0.02)  0.8499 (±0.02)
# fixmatch-nl050-m2-fg1.5-b16  0.8571 (±0.02)  0.8747 (±0.02)  0.8523 (±0.02)
# fixmatch-nl050-m3-fg0.5-b16  0.8627 (±0.02)  0.8821 (±0.03)  0.8559 (±0.01)
# fixmatch-nl050-m3-fg1.0-b16  0.8631 (±0.02)  0.8816 (±0.03)  0.8576 (±0.01)
# fixmatch-nl050-m3-fg1.5-b16  0.8642 (±0.01)  0.8850 (±0.02)  0.8577 (±0.01)
# fixmatch-nl100-m1-fg0.5-b16  0.8692 (±0.01)  0.8864 (±0.01)  0.8619 (±0.02)
# fixmatch-nl100-m1-fg1.0-b16  0.8778 (±0.01)  0.9028 (±0.01)  0.8684 (±0.02)
# fixmatch-nl100-m1-fg1.5-b16  0.8715 (±0.02)  0.8927 (±0.02)  0.8641 (±0.02)
# fixmatch-nl100-m1-fg2.0-b16  0.8706 (±0.01)  0.8931 (±0.02)  0.8658 (±0.02)
# fixmatch-nl100-m2-fg0.5-b16  0.8770 (±0.01)  0.8972 (±0.02)  0.8692 (±0.02)
# fixmatch-nl100-m2-fg1.0-b16  0.8765 (±0.01)  0.9007 (±0.02)  0.8655 (±0.02)
# fixmatch-nl100-m2-fg1.5-b16  0.8740 (±0.01)  0.8983 (±0.02)  0.8640 (±0.02)
# fixmatch-nl100-m3-fg0.5-b16  0.8780 (±0.01)  0.9036 (±0.01)  0.8654 (±0.01)
# fixmatch-nl100-m3-fg1.0-b16  0.8752 (±0.01)  0.9013 (±0.01)  0.8653 (±0.02)
# fixmatch-nl100-m3-fg1.5-b16  0.8721 (±0.01)  0.8951 (±0.01)  0.8635 (±0.02)
# fixmatch-nl150-m1-fg0.5-b16  0.8949 (±0.01)  0.9177 (±0.01)  0.8826 (±0.02)
# fixmatch-nl150-m1-fg1.0-b16  0.8909 (±0.01)  0.9090 (±0.01)  0.8806 (±0.01)
# fixmatch-nl150-m1-fg1.5-b16  0.8964 (±0.01)  0.9172 (±0.01)  0.8880 (±0.02)
# fixmatch-nl150-m2-fg0.5-b16  0.8935 (±0.01)  0.9101 (±0.02)  0.8850 (±0.01)
# fixmatch-nl150-m2-fg1.0-b16  0.8891 (±0.01)  0.9138 (±0.01)  0.8734 (±0.01)
# fixmatch-nl150-m2-fg1.5-b16  0.8918 (±0.01)  0.9165 (±0.01)  0.8779 (±0.02)
#
#                                   f1-normal
# baseline-nl025-m1-fg1.0-b16  0.8063 (±0.04)
# baseline-nl050-m1-fg1.0-b16  0.8387 (±0.02)
# baseline-nl100-m1-fg1.0-b16  0.8578 (±0.02)
# baseline-nl150-m1-fg1.0-b16  0.8719 (±0.01)
# fixmatch-nl025-m1-fg0.5-b16  0.8050 (±0.04)
# fixmatch-nl025-m1-fg1.0-b16  0.8063 (±0.04)
# fixmatch-nl025-m1-fg1.5-b16  0.8061 (±0.04)
# fixmatch-nl025-m2-fg0.5-b16  0.7983 (±0.05)
# fixmatch-nl025-m2-fg1.0-b16  0.8014 (±0.05)
# fixmatch-nl025-m2-fg1.5-b16  0.7982 (±0.05)
# fixmatch-nl025-m3-fg0.5-b16  0.7958 (±0.04)
# fixmatch-nl025-m3-fg1.0-b16  0.7969 (±0.04)
# fixmatch-nl025-m3-fg1.5-b16  0.7982 (±0.04)
# fixmatch-nl050-m1-fg0.5-b16  0.8394 (±0.02)
# fixmatch-nl050-m1-fg1.0-b16  0.8383 (±0.01)
# fixmatch-nl050-m1-fg1.5-b16  0.8459 (±0.01)
# fixmatch-nl050-m2-fg0.5-b16  0.8476 (±0.02)
# fixmatch-nl050-m2-fg1.0-b16  0.8478 (±0.02)
# fixmatch-nl050-m2-fg1.5-b16  0.8443 (±0.02)
# fixmatch-nl050-m3-fg0.5-b16  0.8500 (±0.02)
# fixmatch-nl050-m3-fg1.0-b16  0.8501 (±0.02)
# fixmatch-nl050-m3-fg1.5-b16  0.8498 (±0.01)
# fixmatch-nl100-m1-fg0.5-b16  0.8592 (±0.01)
# fixmatch-nl100-m1-fg1.0-b16  0.8623 (±0.02)
# fixmatch-nl100-m1-fg1.5-b16  0.8576 (±0.02)
# fixmatch-nl100-m1-fg2.0-b16  0.8530 (±0.01)
# fixmatch-nl100-m2-fg0.5-b16  0.8646 (±0.02)
# fixmatch-nl100-m2-fg1.0-b16  0.8631 (±0.02)
# fixmatch-nl100-m2-fg1.5-b16  0.8595 (±0.02)
# fixmatch-nl100-m3-fg0.5-b16  0.8649 (±0.02)
# fixmatch-nl100-m3-fg1.0-b16  0.8589 (±0.01)
# fixmatch-nl100-m3-fg1.5-b16  0.8578 (±0.02)
# fixmatch-nl150-m1-fg0.5-b16  0.8843 (±0.01)
# fixmatch-nl150-m1-fg1.0-b16  0.8830 (±0.01)
# fixmatch-nl150-m1-fg1.5-b16  0.8839 (±0.01)
# fixmatch-nl150-m2-fg0.5-b16  0.8852 (±0.00)
# fixmatch-nl150-m2-fg1.0-b16  0.8801 (±0.01)
# fixmatch-nl150-m2-fg1.5-b16  0.8811 (±0.01)

# %%
# from itertools import permutations
# list(permutations([9, 14, 3]))

# %%
final_metrics_df.to_csv(f'{out_dir}/{out_fname}')
