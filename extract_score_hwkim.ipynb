# %%
import glob
import os
import re
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
from collections import OrderedDict, Callable

class DefaultOrderedDict(OrderedDict):
    # Source: http://stackoverflow.com/a/6190500/562769
    def __init__(self, default_factory=None, *a, **kw):
        if (default_factory is not None and
           not isinstance(default_factory, Callable)):
            raise TypeError('first argument must be callable')
        OrderedDict.__init__(self, *a, **kw)
        self.default_factory = default_factory

    def __getitem__(self, key):
        try:
            return OrderedDict.__getitem__(self, key)
        except KeyError:
            return self.__missing__(key)

    def __missing__(self, key):
        if self.default_factory is None:
            raise KeyError(key)
        self[key] = value = self.default_factory()
        return value

    def __reduce__(self):
        if self.default_factory is None:
            args = tuple()
        else:
            args = self.default_factory,
        return type(self), args, None, None, self.items()

    def copy(self):
        return self.__copy__()

    def __copy__(self):
        return type(self)(self.default_factory, self)

    def __deepcopy__(self, memo):
        import copy
        return type(self)(self.default_factory,
                          copy.deepcopy(self.items()))

    def __repr__(self):
        return 'OrderedDefaultDict(%s, %s)' % (self.default_factory,
                                               OrderedDict.__repr__(self))
# Out:
# /home/wooks/anaconda3/envs/avidnet/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Extract mean score

# %%
# if not os.path.isdir('./results/extracted'):
#     os.mkdir('./results/extracted')

# %%
# p = re.compile('0[.]\d{4}\s\D{2}0[.]\d{2}\D') #[0.숫자4개 +띄어쓰기 + 문자 2개 0.숫자 2개 + 문자 1개
# data_paths = glob.glob('/home/aiffel0042/github_project/AVIDNet/results/*.txt')
# data_paths
# Out:
# []

# %%
# for ori_data_path, data_path in zip(ori_data_paths, data_paths): # 데이터 경로에서 txt파일을 하나씩 불러온다.
#     with open(ori_data_path,'r') as f: 
#         all_data = f.read() # 전체 txt line을 읽어온다.
#         all_data = all_data.split('\n') # 띄어쓰기 기준으로 나눔
#         metric_line = all_data[-6:-2] # hard coding.. 맨 뒤 mean result 부분
#         extract = p.findall(str(metric_line))# 정규표현식에 맞는것만 뽑아내서 extract에 저장
#     with open(data_path,'a') as f:
#         for extract_line in extract:
#             f.write(str(extract_line)+'\n')

# %% [markdown]
# ## Extract mean best scores among all random seeds

# %%
# input_dir = './results/lb25_mu1'
# input_dir = './results/lb50_mu1
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.01'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.005'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.004'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.003'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.002'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.001'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0009'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0008'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0007'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0006'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0005'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0001'
out_dir = './results/extracted_for_best'
# out_fname = 'lb25-mu1-b8,r0,1,2,3.csv'
# out_fname = 'lb50-mu1-b8,r0,1,2,3.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.01.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.005.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.004.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.003.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.002.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.001.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0009.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0008.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0007.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0006.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0005.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0001.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
input_dir = './results/lr_with_warmup/lr0.01'
# input_dir = './results/lr_with_warmup/lr0.009'
# input_dir = './results/lr_with_warmup/lr0.008'
# input_dir = './results/lr_with_warmup/lr0.007'
# input_dir = './results/lr_with_warmup/lr0.006'
# input_dir = './results/lr_with_warmup/lr0.005'
# input_dir = './results/lr_with_warmup/lr0.004'
# input_dir = './results/lr_with_warmup/lr0.003'
# input_dir = './results/lr_with_warmup/lr0.002'
# input_dir = './results/lr_with_warmup/lr0.001'
out_dir = './results/extracted_for_best'
out_fname = 'lr_with_warmup-lr0.01.csv'
# out_fname = 'lr_with_warmup-lr0.009.csv'
# out_fname = 'lr_with_warmup-lr0.008.csv'
# out_fname = 'lr_with_warmup-lr0.007.csv'
# out_fname = 'lr_with_warmup-lr0.006.csv'
# out_fname = 'lr_with_warmup-lr0.005.csv'
# out_fname = 'lr_with_warmup-lr0.004.csv'
# out_fname = 'lr_with_warmup-lr0.003.csv'
# out_fname = 'lr_with_warmup-lr0.002.csv'
# out_fname = 'lr_with_warmup-lr0.001.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# input_dir = './results/fixaugs'
# out_dir = './results/extracted_for_best'
# out_fname = 'fixaugs.csv'
# if not os.path.isdir(out_dir):
#     os.makedirs(out_dir)

# %%
# input_dir = './results/aug_test_for_nl25'
# input_dir = './results/aug_test_for_nl50'
# input_dir = './results/aug_test_for_nl100'
# input_dir = './results/aug_test_for_nl150'
# input_dir = './results/aug_test_for_nl200'
# input_dir = './results/aug_test_for_nl300'
# input_dir = './results/aug_test_for_nl25_accumulated'
# input_dir = './results/aug_test_for_nl50_accumulated'
# input_dir = './results/aug_test_for_nl100_accumulated'
# input_dir = './results/aug_test_for_nl100_accumulated_e40'
input_dir = './results/nl50_aug_result'
out_dir = './results/extracted_for_best'
# out_fname = 'aug_test_for_nl25.csv'
# out_fname = 'aug_test_for_nl50.csv'
# out_fname = 'aug_test_for_nl100.csv'
# out_fname = 'aug_test_for_nl150.csv'
# out_fname = 'aug_test_for_nl200.csv'
# out_fname = 'aug_test_for_nl300.csv'
# out_fname = 'aug_test_for_nl25_accumulated.csv'
# out_fname = 'aug_test_for_nl50_accumulated.csv'
# out_fname = 'aug_test_for_nl100_accumulated.csv'
# out_fname = 'aug_test_for_nl100_accumulated_e40.csv'
out_fname = 'nl50_aug_result.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# input_dir = './results/aug_test_for_fixmatch_nl50'
# input_dir = './results/aug_test_for_fixmatch_nl100'
# input_dir = './results/aug_test_for_fixmatch_nl150'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_0.5'
input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_0.8'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_1.0'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_1.2'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_1.5'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_2.0'
out_dir = './results/extracted_for_best'
# out_fname = 'aug_test_for_fixmatch_nl50.csv'
# out_fname = 'aug_test_for_fixmatch_nl100.csv'
# out_fname = 'aug_test_for_fixmatch_nl150.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma0.5.csv'
out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma0.8.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma1.0.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma1.2.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma1.5.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma2.0.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# input_dir = './results/randaug_tests/k3'
# input_dir = './results/randaug_tests/k5'
# input_dir = './results/randaug_tests/k7'
# input_dir = './results/randaug_tests/k5-fg2'
input_dir = './results/latest_tests'
# input_dir = './results/randaug_tests/fixmatch'
# input_dir = './results/th-lambda_tests'
# input_dir = './results/th-lambda_tests_add'
# input_dir = './results/opt_tests'
# input_dir = './results/sharpen_tests'
# input_dir = './results/decay_tests'
# input_dir = './results/lr_tests'
out_dir = './results/extracted_for_best'
out_fname = 'randaug_tests_for_k5.csv'
# out_fname = 'randaug_tests_for_k7.csv'
add_dir = False
# add_dir = True
# add_input_dirs = ['./results/randaug_tests/k5_f4']
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# ori_data_paths = glob.glob(f'{input_dir}/*.txt')
# # fix_cols = ['th0.95-lb1.0', 'th0.95-lb0.75', 'th0.95-lb0.5',
# #             'th0.98-lb1.0', 'th0.98-lb0.75', 'th0.98-lb0.5']
# # fix_cols = ['aug1-th0.95-lb1.0', 'aug2-th0.95-lb1.0', 'aug3-th0.95-lb1.0']
# # fix_cols = ['aug1-th0.95-lb1.0', 'aug2-th0.95-lb1.0', 'aug3-th0.95-lb1.0']
# # base_cols = [f'bf{i}' for i in range(21)]
# # base_cols = ['bf0', 'bf9', 'bf9,16', 'bf16,9', 'bf16,9,3'] # nl25
# # base_cols = ['bf0', 'bf50:13', 'bf50:13,9', 'bf50:9,13', 'bf50:13,9,7'] # nl50
# # base_cols = ['bf0', 'bf100:9', 'bf14', 'bf100:9,14', 'bf100:14,9', 'bf3', 'bf100:9,14,3'] # nl100
# # base_cols = ['bf9,14', 'bf14,9', 'bf9,14,3', "bf9,3,14", "bf14,9,3", "bf14,3,9", "bf3,9,14", "bf3,14,9"] # nl100_e40
# # base_cols = ["bf13,9", "bf9,13", "bf13,9,8", "bf13,8,9", "bf9,13,8", "bf9,8,13", "bf8,13,9", "bf8,9,13"] # nl100_e40

# # Extract paths for each colums such as baseline, fix-th0.95-lb1.0 and so on
# data_paths_dict = DefaultOrderedDict(list)
# for ori_data_path in ori_data_paths:
#     # Exclude the case of the random seed 4 because of performance
#     if '-r4-' not in ori_data_path:
#         # Baseline
#         if 'baseline' in ori_data_path:
# #             data_paths_dict['baseline'].append(ori_data_path)
#             for base_col in base_cols:
#                 if base_col + '.' in ori_data_path:
#                     data_paths_dict[f'base-{base_col}'].append(ori_data_path)
#                     break
                    
#         # FixMatch
#         else:
#             for fix_col in fix_cols:
#                 if fix_col in ori_data_path:
# #                 if fix_col[:5] in ori_data_path and fix_col[5:] in ori_data_path:
#                     data_paths_dict[f'fix-{fix_col}'].append(ori_data_path)
# #                     data_paths_dict[f'fix{fix_col}'].append(ori_data_path)
#                     break

# data_paths_dict['baseline'][:3]

# %%
ori_data_paths = glob.glob(f'{input_dir}/**/*.txt', recursive=True)
if add_dir:
    for add_input_dir in add_input_dirs:
        ori_data_paths.extend(glob.glob(f'{add_input_dir}/*.txt'))

# Extract paths for each colums such as baseline, fix-th0.95-lb1.0 and so on
fm_cols = []
data_paths_dict = DefaultOrderedDict(list)
for ori_data_path in ori_data_paths:
#     cond = '-'.join(ori_data_path.split('-')[:5])
#     cond = '-'.join(ori_data_path.split('-')[:9])
#     cond = '-'.join(ori_data_path.split('-')[-4:])
#     cond = '-'.join(ori_data_path.split('-')[-2:])
    cond = '-'.join(ori_data_path.split('-'))
    cond = cond.split('/')[-1].replace('nl25', 'nl025')
    cond = cond.split('/')[-1].replace('nl50', 'nl050')
    for r in range(4):
        cond = cond.replace(f'-r{r}', '')
    if cond not in fm_cols:
        fm_cols.append(cond)
    data_paths_dict[cond].append(ori_data_path)
    # Baseline
#     if 'baseline' in ori_data_path:
# #             data_paths_dict['baseline'].append(ori_data_path)
#         for base_col in base_cols:
#             if base_col + '.' in ori_data_path:
#                 data_paths_dict[f'base-{base_col}'].append(ori_data_path)
#                 break

#     # FixMatch
#     else:
#         for fix_col in fix_cols:
#             if fix_col in ori_data_path:
# #                 if fix_col[:5] in ori_data_path and fix_col[5:] in ori_data_path:
#                 data_paths_dict[f'fix-{fix_col}'].append(ori_data_path)
# #                     data_paths_dict[f'fix{fix_col}'].append(ori_data_path)
#                 break

fm_cols.sort()
len(data_paths_dict)
# Out:
# 13

# %%
fm_cols
# Out:
# ['baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1.0-focalFalse-fg1.0-optSGD-lr0.001-mom0.9-sc:step.txt',
#  'fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T1.0-focalFalse-fg1.0-optSGD-lr0.001-mom0.9-sc:no.txt',
#  'fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T1.0-focalTrue-fg0.5-optSGD-lr0.001-mom0.9-sc:no.txt',
#  'fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T1.0-focalTrue-fg1.0-optSGD-lr0.001-mom0.9-sc:no.txt',
#  'fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T1.0-focalTrue-fg1.5-optSGD-lr0.001-mom0.9-sc:no.txt',
#  'fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T1.0-focalFalse-fg1.0-optSGD-lr0.001-mom0.9-sc_no.txt',
#  'fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T1.0-focalTrue-fg0.5-optSGD-lr0.001-mom0.9-sc_no.txt',
#  'fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T1.0-focalTrue-fg1.0-optSGD-lr0.001-mom0.9-sc_no.txt',
#  'fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T1.0-focalTrue-fg1.5-optSGD-lr0.001-mom0.9-sc_no.txt',
#  'fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T1.0-focalFalse-fg1.0-optSGD-lr0.001-mom0.9-sc_no.txt',
#  'fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T1.0-focalTrue-fg0.5-optSGD-lr0.001-mom0.9-sc_no.txt',
#  'fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T1.0-focalTrue-fg1.0-optSGD-lr0.001-mom0.9-sc_no.txt',
#  'fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T1.0-focalTrue-fg1.5-optSGD-lr0.001-mom0.9-sc_no.txt']

# %%
p = re.compile('1[.]\d{4}|0[.]\d{4}') #[0.숫자4개]

cols = ('acc-all', 'ppv-all', 'ppv-covid', 'ppv-pneumonia', 'ppv-normal',
        'recall-all', 'recall-covid', 'recall-pneumonia', 'recall-normal',
        'f1-all', 'f1-covid', 'f1-pneumonia', 'f1-normal')
metrics_dfs = {}
for col, data_paths in data_paths_dict.items(): # 데이터 경로에서 txt파일을 하나씩 불러온다.
    metrics_dfs[col] = pd.DataFrame([], columns=cols)
    for ori_data_path in data_paths:
        with open(ori_data_path, 'r') as f: 
            all_data = f.read() # 전체 txt line을 읽어온다.
            all_data = all_data.split('\n') # 띄어쓰기 기준으로 나눔
            if 'baseline' in ori_data_path:# or 'T' in ori_data_path:
#                 candidates = ((327, 332), (662, 667), (997, 1002),
#                               (1332, 1337), (1667, 1672))
                candidates = ((327, 332), (662, 667), (997, 1002))
#                 candidates = ((647, 652), (1302, 1307), (1957, 1962))
                if add_dir and 'k5_f4' in ori_data_path: # 새로 추가된 Fold 4,5 결과
                    candidates = ((327, 332),)
            else:
#                 candidates = ((347, 352), (702, 707), (1057, 1062),
#                               (1412, 1417), (1767, 1772))
                candidates = ((347, 352), (702, 707), (1057, 1062))
                if add_dir and 'k5_f4' in ori_data_path: # 새로 추가된 Fold 4,5 결과
                    candidates = ((347, 352),)
            metrics = []
            for s_idx, e_idx in candidates:
                metric_line = all_data[s_idx:e_idx] # hard coding.. best result 부분
                metrics.append(list(map(float, p.findall(str(metric_line)))))# 정규표현식에 맞는것만 뽑기

            metrics_dfs[col] = pd.concat((metrics_dfs[col],
                                         pd.DataFrame(metrics, columns=cols))).reset_index(drop=True)

# fm_cols = ['baseline'] + [f'fix-{c}' for c in fix_cols]
# fm_cols = ['baseline'] + [f'fix{c}' for c in fix_cols]
# fm_cols = [f'base-{c}' for c in base_cols]
final_metrics_df = pd.DataFrame([], columns=cols)
for fm_col in fm_cols:
    final_metrics = []
    for col in cols:
        best_metrics = metrics_dfs[fm_col][col].to_numpy()
        mean, std = best_metrics.mean(), best_metrics.std()
        final_metrics.append(f'{mean:.4f} (±{std:.4f})')
        
    final_metrics_df = final_metrics_df.append(pd.DataFrame([final_metrics], columns=cols, index=(fm_col,)))

final_metrics_df
# Out:
#                                                              acc-all  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8383 (±0.0105)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8422 (±0.0139)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8517 (±0.0197)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8489 (±0.0201)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8483 (±0.0212)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8406 (±0.0116)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8472 (±0.0178)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8400 (±0.0214)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8433 (±0.0199)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8461 (±0.0158)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8455 (±0.0204)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8433 (±0.0179)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8444 (±0.0190)
#
#                                                              ppv-all  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8441 (±0.0113)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8492 (±0.0170)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8577 (±0.0198)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8534 (±0.0208)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8508 (±0.0217)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8497 (±0.0120)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8523 (±0.0163)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8442 (±0.0206)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8482 (±0.0206)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8505 (±0.0143)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8535 (±0.0221)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8497 (±0.0173)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8504 (±0.0193)
#
#                                                            ppv-covid  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.9127 (±0.0303)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.9279 (±0.0300)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.9301 (±0.0374)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.9248 (±0.0222)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.9086 (±0.0311)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.9444 (±0.0305)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.9170 (±0.0344)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.9050 (±0.0413)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.9253 (±0.0385)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.9158 (±0.0291)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.9385 (±0.0283)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.9222 (±0.0264)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.9175 (±0.0418)
#
#                                                        ppv-pneumonia  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.7914 (±0.0328)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8351 (±0.0382)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8323 (±0.0445)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8232 (±0.0418)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8102 (±0.0312)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8067 (±0.0307)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8223 (±0.0496)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8044 (±0.0507)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8059 (±0.0303)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8218 (±0.0290)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8130 (±0.0466)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.7965 (±0.0433)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8127 (±0.0534)
#
#                                                           ppv-normal  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8280 (±0.0416)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.7847 (±0.0126)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8106 (±0.0233)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8121 (±0.0090)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8333 (±0.0205)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.7979 (±0.0189)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8177 (±0.0306)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8233 (±0.0231)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8135 (±0.0188)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8141 (±0.0307)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8088 (±0.0204)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8302 (±0.0234)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8210 (±0.0254)
#
#                                                           recall-all  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8383 (±0.0105)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8422 (±0.0139)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8517 (±0.0197)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8489 (±0.0201)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8483 (±0.0212)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8406 (±0.0116)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8472 (±0.0178)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8400 (±0.0214)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8433 (±0.0199)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8461 (±0.0158)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8455 (±0.0204)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8433 (±0.0179)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8444 (±0.0190)
#
#                                                         recall-covid  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8250 (±0.0243)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8133 (±0.0320)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8283 (±0.0367)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8317 (±0.0186)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8617 (±0.0313)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.7900 (±0.0379)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8517 (±0.0495)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8550 (±0.0496)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8283 (±0.0157)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8300 (±0.0416)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.7967 (±0.0213)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8167 (±0.0262)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8333 (±0.0309)
#
#                                                     recall-pneumonia  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8633 (±0.0262)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8350 (±0.0330)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8517 (±0.0227)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8583 (±0.0195)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8483 (±0.0313)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8617 (±0.0227)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8400 (±0.0332)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8433 (±0.0221)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8517 (±0.0376)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8550 (±0.0198)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8750 (±0.0335)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8800 (±0.0238)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8633 (±0.0390)
#
#                                                        recall-normal  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8267 (±0.0340)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8783 (±0.0445)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8750 (±0.0553)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8567 (±0.0537)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8350 (±0.0419)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8700 (±0.0493)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8500 (±0.0560)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8217 (±0.0481)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8500 (±0.0379)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8533 (±0.0309)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8650 (±0.0580)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8333 (±0.0562)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8367 (±0.0496)
#
#                                                               f1-all  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8391 (±0.0106)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8428 (±0.0139)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8522 (±0.0193)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8494 (±0.0201)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8487 (±0.0213)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8411 (±0.0112)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8476 (±0.0169)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8404 (±0.0209)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8441 (±0.0199)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8466 (±0.0156)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8460 (±0.0203)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8438 (±0.0178)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8451 (±0.0188)
#
#                                                             f1-covid  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8662 (±0.0181)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8658 (±0.0107)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8749 (±0.0117)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8754 (±0.0109)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8837 (±0.0153)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8592 (±0.0163)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8814 (±0.0153)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8774 (±0.0190)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8737 (±0.0201)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8695 (±0.0157)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8613 (±0.0112)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8657 (±0.0138)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8720 (±0.0104)
#
#                                                         f1-pneumonia  \
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8251 (±0.0166)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8344 (±0.0274)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8409 (±0.0224)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8399 (±0.0270)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8283 (±0.0239)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8327 (±0.0176)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8294 (±0.0212)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8221 (±0.0226)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8275 (±0.0246)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8377 (±0.0173)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8418 (±0.0279)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8352 (±0.0231)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8353 (±0.0245)
#
#                                                            f1-normal
# baseline-b16-nl050-m1-lb1.0-th1.0-sharpFalse-T1...  0.8262 (±0.0220)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8282 (±0.0189)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8407 (±0.0301)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8329 (±0.0264)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8339 (±0.0291)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8313 (±0.0199)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8321 (±0.0266)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8218 (±0.0290)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8310 (±0.0244)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8326 (±0.0192)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8349 (±0.0303)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8305 (±0.0277)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8279 (±0.0279)

# %%
# from itertools import permutations
# list(permutations([9, 14, 3]))

# %%
final_metrics_df.to_csv(f'{out_dir}/{out_fname}')
