# %%
import glob
import os
import re
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
from collections import OrderedDict, Callable

class DefaultOrderedDict(OrderedDict):
    # Source: http://stackoverflow.com/a/6190500/562769
    def __init__(self, default_factory=None, *a, **kw):
        if (default_factory is not None and
           not isinstance(default_factory, Callable)):
            raise TypeError('first argument must be callable')
        OrderedDict.__init__(self, *a, **kw)
        self.default_factory = default_factory

    def __getitem__(self, key):
        try:
            return OrderedDict.__getitem__(self, key)
        except KeyError:
            return self.__missing__(key)

    def __missing__(self, key):
        if self.default_factory is None:
            raise KeyError(key)
        self[key] = value = self.default_factory()
        return value

    def __reduce__(self):
        if self.default_factory is None:
            args = tuple()
        else:
            args = self.default_factory,
        return type(self), args, None, None, self.items()

    def copy(self):
        return self.__copy__()

    def __copy__(self):
        return type(self)(self.default_factory, self)

    def __deepcopy__(self, memo):
        import copy
        return type(self)(self.default_factory,
                          copy.deepcopy(self.items()))

    def __repr__(self):
        return 'OrderedDefaultDict(%s, %s)' % (self.default_factory,
                                               OrderedDict.__repr__(self))
# Out:
# /home/wooks/anaconda3/envs/avidnet/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Extract mean score

# %%
# if not os.path.isdir('./results/extracted'):
#     os.mkdir('./results/extracted')

# %%
# p = re.compile('0[.]\d{4}\s\D{2}0[.]\d{2}\D') #[0.숫자4개 +띄어쓰기 + 문자 2개 0.숫자 2개 + 문자 1개
# data_paths = glob.glob('/home/aiffel0042/github_project/AVIDNet/results/*.txt')
# data_paths
# Out:
# []

# %%
# for ori_data_path, data_path in zip(ori_data_paths, data_paths): # 데이터 경로에서 txt파일을 하나씩 불러온다.
#     with open(ori_data_path,'r') as f: 
#         all_data = f.read() # 전체 txt line을 읽어온다.
#         all_data = all_data.split('\n') # 띄어쓰기 기준으로 나눔
#         metric_line = all_data[-6:-2] # hard coding.. 맨 뒤 mean result 부분
#         extract = p.findall(str(metric_line))# 정규표현식에 맞는것만 뽑아내서 extract에 저장
#     with open(data_path,'a') as f:
#         for extract_line in extract:
#             f.write(str(extract_line)+'\n')

# %% [markdown]
# ## Extract mean best scores among all random seeds

# %%
# input_dir = './results/lb25_mu1'
# input_dir = './results/lb50_mu1
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.01'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.005'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.004'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.003'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.002'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.001'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0009'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0008'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0007'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0006'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0005'
# input_dir = './results/nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0001'
out_dir = './results/extracted_for_best'
# out_fname = 'lb25-mu1-b8,r0,1,2,3.csv'
# out_fname = 'lb50-mu1-b8,r0,1,2,3.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.01.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.005.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.004.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.003.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.002.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.001.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0009.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0008.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0007.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0006.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0005.csv'
# out_fname = 'nl25-m1-b16-r0,1,2-th0.95-lb1.0-sc:step-lr0.0001.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
input_dir = './results/lr_with_warmup/lr0.01'
# input_dir = './results/lr_with_warmup/lr0.009'
# input_dir = './results/lr_with_warmup/lr0.008'
# input_dir = './results/lr_with_warmup/lr0.007'
# input_dir = './results/lr_with_warmup/lr0.006'
# input_dir = './results/lr_with_warmup/lr0.005'
# input_dir = './results/lr_with_warmup/lr0.004'
# input_dir = './results/lr_with_warmup/lr0.003'
# input_dir = './results/lr_with_warmup/lr0.002'
# input_dir = './results/lr_with_warmup/lr0.001'
out_dir = './results/extracted_for_best'
out_fname = 'lr_with_warmup-lr0.01.csv'
# out_fname = 'lr_with_warmup-lr0.009.csv'
# out_fname = 'lr_with_warmup-lr0.008.csv'
# out_fname = 'lr_with_warmup-lr0.007.csv'
# out_fname = 'lr_with_warmup-lr0.006.csv'
# out_fname = 'lr_with_warmup-lr0.005.csv'
# out_fname = 'lr_with_warmup-lr0.004.csv'
# out_fname = 'lr_with_warmup-lr0.003.csv'
# out_fname = 'lr_with_warmup-lr0.002.csv'
# out_fname = 'lr_with_warmup-lr0.001.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# input_dir = './results/fixaugs'
# out_dir = './results/extracted_for_best'
# out_fname = 'fixaugs.csv'
# if not os.path.isdir(out_dir):
#     os.makedirs(out_dir)

# %%
# input_dir = './results/aug_test_for_nl25'
# input_dir = './results/aug_test_for_nl50'
# input_dir = './results/aug_test_for_nl100'
# input_dir = './results/aug_test_for_nl150'
# input_dir = './results/aug_test_for_nl200'
# input_dir = './results/aug_test_for_nl300'
# input_dir = './results/aug_test_for_nl25_accumulated'
# input_dir = './results/aug_test_for_nl50_accumulated'
# input_dir = './results/aug_test_for_nl100_accumulated'
# input_dir = './results/aug_test_for_nl100_accumulated_e40'
input_dir = './results/nl50_aug_result'
out_dir = './results/extracted_for_best'
# out_fname = 'aug_test_for_nl25.csv'
# out_fname = 'aug_test_for_nl50.csv'
# out_fname = 'aug_test_for_nl100.csv'
# out_fname = 'aug_test_for_nl150.csv'
# out_fname = 'aug_test_for_nl200.csv'
# out_fname = 'aug_test_for_nl300.csv'
# out_fname = 'aug_test_for_nl25_accumulated.csv'
# out_fname = 'aug_test_for_nl50_accumulated.csv'
# out_fname = 'aug_test_for_nl100_accumulated.csv'
# out_fname = 'aug_test_for_nl100_accumulated_e40.csv'
out_fname = 'nl50_aug_result.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# input_dir = './results/aug_test_for_fixmatch_nl50'
# input_dir = './results/aug_test_for_fixmatch_nl100'
# input_dir = './results/aug_test_for_fixmatch_nl150'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_0.5'
input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_0.8'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_1.0'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_1.2'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_1.5'
# input_dir = './results/aug_test_for_fixmatch_with_focal_loss_nl100/gamma_2.0'
out_dir = './results/extracted_for_best'
# out_fname = 'aug_test_for_fixmatch_nl50.csv'
# out_fname = 'aug_test_for_fixmatch_nl100.csv'
# out_fname = 'aug_test_for_fixmatch_nl150.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma0.5.csv'
out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma0.8.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma1.0.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma1.2.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma1.5.csv'
# out_fname = 'aug_test_for_fixmatch_with_focal_loss_nl100_gamma2.0.csv'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# input_dir = './results/randaug_tests/k3'
# input_dir = './results/randaug_tests/k5'
# input_dir = './results/randaug_tests/k7'
# input_dir = './results/randaug_tests/k5-fg2'
input_dir = './results/latest_tests'
input_dir = './results/latest_tests/gamma_tests/nl50'
# input_dir = './results/latest_tests/opt_tests'
# input_dir = './results/latest_tests/decay_tests'
# input_dir = './results/latest_tests/th_tests'
# input_dir = './results/latest_tests/lambda_tests'
# input_dir = './results/randaug_tests/fixmatch'
# input_dir = './results/th-lambda_tests'
# input_dir = './results/th-lambda_tests_add'
# input_dir = './results/opt_tests'
# input_dir = './results/sharpen_tests'
# input_dir = './results/decay_tests'
# input_dir = './results/lr_tests'
out_dir = './results/extracted_for_best'
out_fname = 'randaug_tests_for_k5.csv'
# out_fname = 'randaug_tests_for_k7.csv'
add_dir = False
# add_dir = True
# add_input_dirs = ['./results/randaug_tests/k5_f4']
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
# ori_data_paths = glob.glob(f'{input_dir}/*.txt')
# # fix_cols = ['th0.95-lb1.0', 'th0.95-lb0.75', 'th0.95-lb0.5',
# #             'th0.98-lb1.0', 'th0.98-lb0.75', 'th0.98-lb0.5']
# # fix_cols = ['aug1-th0.95-lb1.0', 'aug2-th0.95-lb1.0', 'aug3-th0.95-lb1.0']
# # fix_cols = ['aug1-th0.95-lb1.0', 'aug2-th0.95-lb1.0', 'aug3-th0.95-lb1.0']
# # base_cols = [f'bf{i}' for i in range(21)]
# # base_cols = ['bf0', 'bf9', 'bf9,16', 'bf16,9', 'bf16,9,3'] # nl25
# # base_cols = ['bf0', 'bf50:13', 'bf50:13,9', 'bf50:9,13', 'bf50:13,9,7'] # nl50
# # base_cols = ['bf0', 'bf100:9', 'bf14', 'bf100:9,14', 'bf100:14,9', 'bf3', 'bf100:9,14,3'] # nl100
# # base_cols = ['bf9,14', 'bf14,9', 'bf9,14,3', "bf9,3,14", "bf14,9,3", "bf14,3,9", "bf3,9,14", "bf3,14,9"] # nl100_e40
# # base_cols = ["bf13,9", "bf9,13", "bf13,9,8", "bf13,8,9", "bf9,13,8", "bf9,8,13", "bf8,13,9", "bf8,9,13"] # nl100_e40

# # Extract paths for each colums such as baseline, fix-th0.95-lb1.0 and so on
# data_paths_dict = DefaultOrderedDict(list)
# for ori_data_path in ori_data_paths:
#     # Exclude the case of the random seed 4 because of performance
#     if '-r4-' not in ori_data_path:
#         # Baseline
#         if 'baseline' in ori_data_path:
# #             data_paths_dict['baseline'].append(ori_data_path)
#             for base_col in base_cols:
#                 if base_col + '.' in ori_data_path:
#                     data_paths_dict[f'base-{base_col}'].append(ori_data_path)
#                     break
                    
#         # FixMatch
#         else:
#             for fix_col in fix_cols:
#                 if fix_col in ori_data_path:
# #                 if fix_col[:5] in ori_data_path and fix_col[5:] in ori_data_path:
#                     data_paths_dict[f'fix-{fix_col}'].append(ori_data_path)
# #                     data_paths_dict[f'fix{fix_col}'].append(ori_data_path)
#                     break

# data_paths_dict['baseline'][:3]

# %%
ori_data_paths = glob.glob(f'{input_dir}/**/*.txt', recursive=True)
if add_dir:
    for add_input_dir in add_input_dirs:
        ori_data_paths.extend(glob.glob(f'{add_input_dir}/*.txt'))

# Extract paths for each colums such as baseline, fix-th0.95-lb1.0 and so on
fm_cols = []
data_paths_dict = DefaultOrderedDict(list)
for ori_data_path in ori_data_paths:
#     cond = '-'.join(ori_data_path.split('-')[:5])
#     cond = '-'.join(ori_data_path.split('-')[:9])
#     cond = '-'.join(ori_data_path.split('-')[-4:])
#     cond = '-'.join(ori_data_path.split('-')[-2:])
    cond = '-'.join(ori_data_path.split('-'))
    cond = cond.split('/')[-1].replace('nl25', 'nl025')
    cond = cond.split('/')[-1].replace('nl50', 'nl050')
    for r in range(4):
        cond = cond.replace(f'-r{r}', '')
    if cond not in fm_cols:
        fm_cols.append(cond)
    data_paths_dict[cond].append(ori_data_path)
    # Baseline
#     if 'baseline' in ori_data_path:
# #             data_paths_dict['baseline'].append(ori_data_path)
#         for base_col in base_cols:
#             if base_col + '.' in ori_data_path:
#                 data_paths_dict[f'base-{base_col}'].append(ori_data_path)
#                 break

#     # FixMatch
#     else:
#         for fix_col in fix_cols:
#             if fix_col in ori_data_path:
# #                 if fix_col[:5] in ori_data_path and fix_col[5:] in ori_data_path:
#                 data_paths_dict[f'fix-{fix_col}'].append(ori_data_path)
# #                     data_paths_dict[f'fix{fix_col}'].append(ori_data_path)
#                 break

fm_cols.sort()
len(data_paths_dict)
# Out:
# 11

# %%
p = re.compile('1[.]\d{4}|0[.]\d{4}') #[0.숫자4개]

cols = ('acc-all', 'ppv-all', 'ppv-covid', 'ppv-pneumonia', 'ppv-normal',
        'recall-all', 'recall-covid', 'recall-pneumonia', 'recall-normal',
        'f1-all', 'f1-covid', 'f1-pneumonia', 'f1-normal')
metrics_dfs = {}
for col, data_paths in data_paths_dict.items(): # 데이터 경로에서 txt파일을 하나씩 불러온다.
    metrics_dfs[col] = pd.DataFrame([], columns=cols)
    for ori_data_path in data_paths:
        with open(ori_data_path, 'r') as f: 
            all_data = f.read() # 전체 txt line을 읽어온다.
            all_data = all_data.split('\n') # 띄어쓰기 기준으로 나눔
            if 'baseline' in ori_data_path or 'sharpTrue' in ori_data_path:
#                 candidates = ((327, 332), (662, 667), (997, 1002),
#                               (1332, 1337), (1667, 1672))
                candidates = ((327, 332), (662, 667), (997, 1002), (1332, 1337))
#                 candidates = ((647, 652), (1302, 1307), (1957, 1962))
                if add_dir and 'k5_f4' in ori_data_path: # 새로 추가된 Fold 4,5 결과
                    candidates = ((327, 332),)
            else:
#                 candidates = ((347, 352), (702, 707), (1057, 1062),
#                               (1412, 1417), (1767, 1772))
                candidates = ((347, 352), (702, 707), (1057, 1062), (1412, 1417))
                if add_dir and 'k5_f4' in ori_data_path: # 새로 추가된 Fold 4,5 결과
                    candidates = ((347, 352),)
            metrics = []
            for s_idx, e_idx in candidates:
                metric_line = all_data[s_idx:e_idx] # hard coding.. best result 부분
                metrics.append(list(map(float, p.findall(str(metric_line)))))# 정규표현식에 맞는것만 뽑기

            metrics_dfs[col] = pd.concat((metrics_dfs[col],
                                         pd.DataFrame(metrics, columns=cols))).reset_index(drop=True)

# fm_cols = ['baseline'] + [f'fix-{c}' for c in fix_cols]
# fm_cols = ['baseline'] + [f'fix{c}' for c in fix_cols]
# fm_cols = [f'base-{c}' for c in base_cols]
final_metrics_df = pd.DataFrame([], columns=cols)
for fm_col in fm_cols:
    final_metrics = []
    for col in cols:
        best_metrics = metrics_dfs[fm_col][col].to_numpy()
        mean, std = best_metrics.mean(), best_metrics.std()
        final_metrics.append(f'{mean:.4f} (±{std:.4f})')
        
    final_metrics_df = final_metrics_df.append(pd.DataFrame([final_metrics], columns=cols, index=(fm_col,)))

final_metrics_df
# Out:
#                                                              acc-all  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8571 (±0.0195)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8546 (±0.0201)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8529 (±0.0201)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8529 (±0.0237)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8504 (±0.0240)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8521 (±0.0176)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8475 (±0.0227)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8521 (±0.0233)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8508 (±0.0216)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8496 (±0.0203)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8504 (±0.0199)
#
#                                                              ppv-all  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8620 (±0.0188)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8584 (±0.0202)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8551 (±0.0204)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8547 (±0.0233)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8533 (±0.0219)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8561 (±0.0156)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8507 (±0.0212)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8559 (±0.0227)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8569 (±0.0216)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8543 (±0.0186)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8550 (±0.0189)
#
#                                                            ppv-covid  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.9202 (±0.0385)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.9202 (±0.0212)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.9021 (±0.0316)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8946 (±0.0278)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.9053 (±0.0230)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.9078 (±0.0347)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8992 (±0.0374)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.9160 (±0.0374)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.9249 (±0.0341)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.9118 (±0.0295)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.9092 (±0.0394)
#
#                                                        ppv-pneumonia  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8371 (±0.0396)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8350 (±0.0447)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8185 (±0.0308)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8307 (±0.0490)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8254 (±0.0301)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8367 (±0.0501)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8223 (±0.0545)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8271 (±0.0466)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8261 (±0.0477)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8127 (±0.0479)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8239 (±0.0507)
#
#                                                           ppv-normal  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8287 (±0.0398)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8199 (±0.0161)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8447 (±0.0305)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8389 (±0.0242)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8291 (±0.0408)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8240 (±0.0293)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8307 (±0.0238)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8246 (±0.0261)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8196 (±0.0290)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8384 (±0.0260)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8318 (±0.0307)
#
#                                                           recall-all  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8571 (±0.0195)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8546 (±0.0201)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8529 (±0.0201)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8529 (±0.0237)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8504 (±0.0240)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8521 (±0.0176)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8475 (±0.0227)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8521 (±0.0233)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8508 (±0.0216)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8496 (±0.0203)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8504 (±0.0199)
#
#                                                         recall-covid  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8413 (±0.0417)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8413 (±0.0237)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8688 (±0.0314)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8762 (±0.0360)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8538 (±0.0441)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8575 (±0.0447)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8650 (±0.0464)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8487 (±0.0392)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8162 (±0.0406)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8337 (±0.0374)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8438 (±0.0331)
#
#                                                     recall-pneumonia  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8613 (±0.0262)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8587 (±0.0196)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8587 (±0.0330)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8475 (±0.0254)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8513 (±0.0392)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8400 (±0.0287)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8438 (±0.0193)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8513 (±0.0326)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8725 (±0.0303)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8775 (±0.0233)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8662 (±0.0350)
#
#                                                        recall-normal  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8687 (±0.0513)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8638 (±0.0497)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8313 (±0.0382)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8350 (±0.0497)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8462 (±0.0264)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8588 (±0.0509)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8337 (±0.0466)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8563 (±0.0346)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8638 (±0.0505)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8375 (±0.0502)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8412 (±0.0437)
#
#                                                               f1-all  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8574 (±0.0191)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8550 (±0.0201)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8531 (±0.0201)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8530 (±0.0236)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8507 (±0.0238)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8524 (±0.0169)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8478 (±0.0222)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8526 (±0.0231)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8512 (±0.0214)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8499 (±0.0202)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8509 (±0.0196)
#
#                                                             f1-covid  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8772 (±0.0111)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8785 (±0.0109)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8842 (±0.0134)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8844 (±0.0131)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8780 (±0.0256)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8803 (±0.0134)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8801 (±0.0171)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8800 (±0.0206)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8658 (±0.0138)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8699 (±0.0145)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8738 (±0.0096)
#
#                                                         f1-pneumonia  \
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8483 (±0.0236)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8461 (±0.0259)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8378 (±0.0266)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8381 (±0.0277)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8375 (±0.0259)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8369 (±0.0227)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8316 (±0.0263)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8380 (±0.0286)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8476 (±0.0279)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8429 (±0.0259)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8431 (±0.0262)
#
#                                                            f1-normal
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8468 (±0.0281)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8405 (±0.0267)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8374 (±0.0260)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8365 (±0.0346)
# fixmatch-b16-nl050-m1-lb1.0-th0.95-sharpFalse-T...  0.8367 (±0.0232)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8399 (±0.0268)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8317 (±0.0304)
# fixmatch-b16-nl050-m2-lb1.0-th0.95-sharpFalse-T...  0.8398 (±0.0265)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8402 (±0.0293)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8370 (±0.0280)
# fixmatch-b16-nl050-m3-lb1.0-th0.95-sharpFalse-T...  0.8358 (±0.0280)

# %%
# from itertools import permutations
# list(permutations([9, 14, 3]))

# %%
final_metrics_df.to_csv(f'{out_dir}/{out_fname}')
